# %% [markdown]
# <a href="https://colab.research.google.com/github/HardikB16/Dataset/blob/main/RegressionML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install Quandl
# Out:
#   File "<ipython-input-78-953376dcd631>", line 2
#     pip install pickle
#         ^
# SyntaxError: invalid syntax

# %%
#pip install scikit-learn

# %%
#pip install numpy

# %%
#pip install pandas

# %%
import quandl
import pandas as pd
import math

df = quandl.get('WIKI/GOOGL')
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# ...

# %%
df1 = df[["Adj. Open","Adj. High","Adj. Low","Adj. Close","Adj. Volume"]]
df1.head()
# Out:
#             Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# Date
# 2004-08-19  50.159839  52.191109  48.128568   50.322842   44659000.0
# 2004-08-20  50.661387  54.708881  50.405597   54.322689   22834300.0
# 2004-08-23  55.551482  56.915693  54.693835   54.869377   18256100.0
# 2004-08-24  55.792225  55.972783  51.945350   52.597363   15247300.0
# 2004-08-25  52.542193  54.167209  52.100830   53.164113    9188600.0

# %%
df1.describe()
# Out:
#          Adj. Open    Adj. High     Adj. Low   Adj. Close   Adj. Volume
# count  3424.000000  3424.000000  3424.000000  3424.000000  3.424000e+03
# mean    409.221461   412.786556   405.227809   409.057885  7.818568e+06
# std     257.844081   259.366718   255.981628   257.773495  8.248211e+06
# min      49.698414    51.027517    48.128568    50.159839  5.211410e+05
# 25%     231.292728   233.416785   228.738594   231.316552  2.430647e+06
# 50%     300.174109   302.496277   297.909618   300.264387  5.076200e+06
# 75%     561.178118   565.000000   556.673036   561.200000  1.020910e+07
# max    1188.000000  1198.000000  1184.060000  1187.560000  8.215110e+07

# %%
df1["HL_PCT"] = (df1["Adj. High"] -  df1["Adj. Close"]) / df1["Adj. Close"] * 100.0
df1["PCT_change"] = (df1["Adj. Close"] - df1["Adj. Open"]) / df1["Adj. Open"] * 100.0

df1 =  df1[["Adj. Close","Adj. Volume","HL_PCT","PCT_change"]]
df1.head()
# Out:
# <ipython-input-90-0430bcad538d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["HL_PCT"] = (df1["Adj. High"] -  df1["Adj. Close"]) / df1["Adj. Close"] * 100.0
# <ipython-input-90-0430bcad538d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["PCT_change"] = (df1["Adj. Close"] - df1["Adj. Open"]) / df1["Adj. Open"] * 100.0
#             Adj. Close  Adj. Volume    HL_PCT  PCT_change
# Date
# 2004-08-19   50.322842   44659000.0  3.712563    0.324968
# ...

# %%
import math

forecase_col = "Adj. Close"
df1.fillna(-9999,inplace = True)
forecast_out = int(math.ceil(0.01*len(df1)))
df1["label"] = df1[forecase_col].shift(-forecast_out)
df1.dropna(inplace = True)
df1.head()
# Out:
# <ipython-input-91-3095f9bd633e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.fillna(-9999,inplace = True)
# <ipython-input-91-3095f9bd633e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["label"] = df1[forecase_col].shift(-forecast_out)
# <ipython-input-91-3095f9bd633e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
from sklearn.model_selection import cross_validate, train_test_split
from sklearn import preprocessing, svm
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
X = np.array(df1.drop('label', axis=1))                                 ## Speicfy axis
#X = np.array(df1[["Adj. Close","Adj. Volume","HL_PCT","PCT_change"]])   ##Features
y = np.array(df1["label"])               ##Labels

X = preprocessing.scale(X)

X_train, X_test , y_train, Y_test  = train_test_split(X,y,test_size = 0.1)

# %%
clf = LinearRegression()
clf.fit(X_train,y_train)
accuracy = clf.score(X_test,Y_test)
print(accuracy)
# Out:
# 0.9766068243437545

# %%
clf = svm.SVR()
clf.fit(X_train,y_train)
accuracy = clf.score(X_test,Y_test)
print(accuracy)
# Out:
# 0.8024065212308654

# %% [markdown]
# **Forecasting in the future**

# %%
X = np.array(df1.drop(['label'],axis = 1))
X = preprocessing.scale(X)
X_lately = X[-forecast_out:]
X = X[:-forecast_out:]

df1.dropna(inplace = True)
y = np.array(df1["label"])
y = y[:-forecast_out]

X_train, X_test , y_train, Y_test  = train_test_split(X,y,test_size = 0.1)

# %%
data_prediction = clf.predict(X_predict)
print(data_prediction)
# Out:
# [362.82153668 362.82153668 362.82153668 362.82153668 362.82153668
#  362.82153668 362.82153668 362.82153668 362.82153668 362.82153668
#  362.82153668 362.82153668 362.82153668 362.82153668 362.82153668
#  362.82153668 362.82153668 362.82153668 362.82153668 362.82153668
#  362.82153668 362.82153668 362.82153668 362.82153668 362.82153668
#  362.82153668 362.82153668 362.82153668 362.82153668 362.82153668
#  362.82153668 362.82153668 362.82153668 362.82153668 362.82153668]

# %% [markdown]
# **Picking and Scaling**

# %%
import pickle

# %%
clf = LinearRegression()
clf.fit(X_train,y_train)

with open('linearregression.pickle','wb') as f:   #To save the classifier
  pickle.dump(clf,f)

pickle_in = open('linearregression.pickle','rb')   # To access the classifier
clf = pickle.load(pickle_in)
